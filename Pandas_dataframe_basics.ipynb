# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('bank.csv')

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
len(df)
# Out:
# 41188

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df['age']
# Out:
# 0        56
# 1        57
# 2        37
# 3        40
# 4        56
#          ..
# 41183    73
# 41184    46
# 41185    56
# 41186    44
# 41187    74
# Name: age, Length: 41188, dtype: int64

# %%
df[["age", "job"]]
# Out:
#        age          job
# 0       56    housemaid
# 1       57     services
# 2       37     services
# 3       40       admin.
# 4       56     services
# ...    ...          ...
# 41183   73      retired
# 41184   46  blue-collar
# 41185   56      retired
# 41186   44   technician
# 41187   74      retired
#
# [41188 rows x 2 columns]

# %%
df[["age", "job"]].head()
# Out:
#    age        job
# 0   56  housemaid
# 1   57   services
# 2   37   services
# 3   40     admin.
# 4   56   services

# %%
df.age.head()
# Out:
# 0    56
# 1    57
# 2    37
# 3    40
# 4    56
# Name: age, dtype: int64

# %%
df.age.mean()
# Out:
# 40.02406040594348

# %%
df.age.std()
# Out:
# 10.421249980934235

# %%
df.age.hist()

# %%
df = df.drop(["marital"],axis = 1)
df.columns
# Out:
# Index(['age', 'job', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
empty = df.apply(lambda col: pandas.isnull(col))
empty
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d3ee11bcf307> in <module>
# ----> 1 empty = df.apply(lambda col: pandas.isnull(col))
#       2 empty
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# ...

# %%
df.age.head()
# Out:
# 0    56
# 1    57
# 2    37
# 3    40
# 4    56
# Name: age, dtype: int64

# %%
df
# Out:
#        age          job            education  default housing loan    contact  \
# 0       56    housemaid             basic.4y       no      no   no  telephone
# 1       57     services          high.school  unknown      no   no  telephone
# 2       37     services          high.school       no     yes   no  telephone
# 3       40       admin.             basic.6y       no      no   no  telephone
# 4       56     services          high.school       no      no  yes  telephone
# ...    ...          ...                  ...      ...     ...  ...        ...
# 41183   73      retired  professional.course       no     yes   no   cellular
# 41184   46  blue-collar  professional.course       no      no   no   cellular
# 41185   56      retired    university.degree       no     yes   no   cellular
# 41186   44   technician  professional.course       no      no   no   cellular
# 41187   74      retired  professional.course       no     yes   no   cellular
#
# ...

# %%
df.dropna(subset = ["loan"])
# Out:
#        age          job            education  default housing loan    contact  \
# 0       56    housemaid             basic.4y       no      no   no  telephone
# 1       57     services          high.school  unknown      no   no  telephone
# 2       37     services          high.school       no     yes   no  telephone
# 3       40       admin.             basic.6y       no      no   no  telephone
# 4       56     services          high.school       no      no  yes  telephone
# ...    ...          ...                  ...      ...     ...  ...        ...
# 41183   73      retired  professional.course       no     yes   no   cellular
# 41184   46  blue-collar  professional.course       no      no   no   cellular
# 41185   56      retired    university.degree       no     yes   no   cellular
# 41186   44   technician  professional.course       no      no   no   cellular
# 41187   74      retired  professional.course       no     yes   no   cellular
#
# ...

# %%
df.isnull()
# Out:
#          age    job  education  default  housing   loan  contact  month  \
# 0      False  False      False    False    False  False    False  False
# 1      False  False      False    False    False  False    False  False
# 2      False  False      False    False    False  False    False  False
# 3      False  False      False    False    False  False    False  False
# 4      False  False      False    False    False  False    False  False
# ...      ...    ...        ...      ...      ...    ...      ...    ...
# 41183  False  False      False    False    False  False    False  False
# 41184  False  False      False    False    False  False    False  False
# 41185  False  False      False    False    False  False    False  False
# 41186  False  False      False    False    False  False    False  False
# 41187  False  False      False    False    False  False    False  False
#
#        day_of_week  duration  campaign  pdays  previous  poutcome  \
# ...

# %%
df.irow(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-f02acebe4ce8> in <module>
# ----> 1 df.irow(0)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'irow'

# %%
num_service = 0
for idx, row in df.iterrows():
    if "services" in row["job"]:
        num_service += 1

"People in service {0}".format(num_service)
# Out:
# 'People in service 3969'

# %%
df
# Out:
#        age          job            education  default housing loan    contact  \
# 0       56    housemaid             basic.4y       no      no   no  telephone
# 1       57     services          high.school  unknown      no   no  telephone
# 2       37     services          high.school       no     yes   no  telephone
# 3       40       admin.             basic.6y       no      no   no  telephone
# 4       56     services          high.school       no      no  yes  telephone
# ...    ...          ...                  ...      ...     ...  ...        ...
# 41183   73      retired  professional.course       no     yes   no   cellular
# 41184   46  blue-collar  professional.course       no      no   no   cellular
# 41185   56      retired    university.degree       no     yes   no   cellular
# 41186   44   technician  professional.course       no      no   no   cellular
# 41187   74      retired  professional.course       no     yes   no   cellular
#
# ...

# %%
dfservice = df[df.job == "services"]

# %%
dfservice
# Out:
#        age       job          education  default  housing     loan    contact  \
# 1       57  services        high.school  unknown       no       no  telephone
# 2       37  services        high.school       no      yes       no  telephone
# 4       56  services        high.school       no       no      yes  telephone
# 5       45  services           basic.9y  unknown       no       no  telephone
# 9       25  services        high.school       no      yes       no  telephone
# ...    ...       ...                ...      ...      ...      ...        ...
# 41079   51  services        high.school       no      yes       no   cellular
# 41096   28  services        high.school       no      yes       no   cellular
# 41115   42  services  university.degree       no  unknown  unknown   cellular
# 41139   31  services        high.school       no      yes       no   cellular
# 41169   62  services        high.school       no      yes       no   cellular
#
# ...

# %%
df[df.housing == "no"]
# Out:
#        age           job            education  default housing loan  \
# 0       56     housemaid             basic.4y       no      no   no
# 1       57      services          high.school  unknown      no   no
# 3       40        admin.             basic.6y       no      no   no
# 4       56      services          high.school       no      no  yes
# 5       45      services             basic.9y  unknown      no   no
# ...    ...           ...                  ...      ...     ...  ...
# 41168   38  entrepreneur    university.degree       no      no   no
# 41178   62       retired    university.degree       no      no   no
# 41180   36        admin.    university.degree       no      no   no
# 41184   46   blue-collar  professional.course       no      no   no
# 41186   44    technician  professional.course       no      no   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 0      telephone   may         mon       261         1    999         0
# ...

# %%
yes = df.y == "yes"

# %%
type(yes)
# Out:
# pandas.core.series.Series

# %%
df[yes]
# Out:
#        age           job            education  default housing loan  \
# 75      41   blue-collar             basic.4y  unknown     yes   no
# 83      49  entrepreneur    university.degree  unknown     yes   no
# 88      49    technician             basic.9y       no      no   no
# 129     41    technician  professional.course  unknown     yes   no
# 139     45   blue-collar             basic.9y  unknown     yes   no
# ...    ...           ...                  ...      ...     ...  ...
# 41174   62       retired    university.degree       no     yes   no
# 41178   62       retired    university.degree       no      no   no
# 41181   37        admin.    university.degree       no     yes   no
# 41183   73       retired  professional.course       no     yes   no
# 41186   44    technician  professional.course       no      no   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 75     telephone   may         mon      1575         1    999         0
# ...

# %%
moredur = df.duration > 1000

# %%
moredur
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 41183    False
# 41184    False
# 41185    False
# 41186    False
# 41187    False
# Name: duration, Length: 41188, dtype: bool

# %%
cover_temps = {}
for cover, cover_data in df.groupby("month"):
    cover_temps["duration"] = cover_data.duration.mean()  # The mean mean temp!
cover_temps
# Out:
# {'duration': 297.70526315789476}

# %%
df.age.unique()
# Out:
# array([56, 57, 37, 40, 45, 59, 41, 24, 25, 29, 35, 54, 46, 50, 39, 30, 55,
#        49, 34, 52, 58, 32, 38, 44, 42, 60, 53, 47, 51, 48, 33, 31, 43, 36,
#        28, 27, 26, 22, 23, 20, 21, 61, 19, 18, 70, 66, 76, 67, 73, 88, 95,
#        77, 68, 75, 63, 80, 62, 65, 72, 82, 64, 71, 69, 78, 85, 79, 83, 81,
#        74, 17, 87, 91, 86, 98, 94, 84, 92, 89])

# %%
df.contact.unique()
# Out:
# array(['telephone', 'cellular'], dtype=object)

# %%
for contact_kind in ["telephone", "cellular"]:
    col_name = contact_kind.upper()  # Turn "Rain" into "rain", etc.
    df[col_name] = df.conact.apply(lambda e: contact_kind in e)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-9191111ba5d5> in <module>
#       1 for contact_kind in ["telephone", "cellular"]:
#       2     col_name = contact_kind.upper()  # Turn "Rain" into "rain", etc.
# ----> 3     df[col_name] = df.conact.apply(lambda e: contact_kind in e)
#       4 df
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'conact'

# %%
df.age.mean()
# Out:
# 40.02406040594348

# %%
df.age.tail().plot()

# %%
df.tail()
# Out:
#        age          job            education default housing loan   contact  \
# 41183   73      retired  professional.course      no     yes   no  cellular
# 41184   46  blue-collar  professional.course      no      no   no  cellular
# 41185   56      retired    university.degree      no     yes   no  cellular
# 41186   44   technician  professional.course      no      no   no  cellular
# 41187   74      retired  professional.course      no     yes   no  cellular
#
#       month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 41183   nov         fri       334         1    999         0  nonexistent
# 41184   nov         fri       383         1    999         0  nonexistent
# 41185   nov         fri       189         2    999         0  nonexistent
# 41186   nov         fri       442         1    999         0  nonexistent
# 41187   nov         fri       239         3    999         1      failure
#
# ...

# %%
df.groupby("job")

# %%
df.head()
# Out:
#    age        job    education  default housing loan    contact month  \
# 0   56  housemaid     basic.4y       no      no   no  telephone   may
# 1   57   services  high.school  unknown      no   no  telephone   may
# 2   37   services  high.school       no     yes   no  telephone   may
# 3   40     admin.     basic.6y       no      no   no  telephone   may
# 4   56   services  high.school       no      no  yes  telephone   may
#
#   day_of_week  duration  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0         mon       261         1    999         0  nonexistent           1.1
# 1         mon       149         1    999         0  nonexistent           1.1
# 2         mon       226         1    999         0  nonexistent           1.1
# 3         mon       151         1    999         0  nonexistent           1.1
# 4         mon       307         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df.age.head().plot()

# %%
df.age.tail().plot(kind="bar", rot=10)

# %%
ax = df.age.plot(title="AGE")
#df.age.plot(style="red", ax=ax)

# %%
df.to_csv("bank2.csv")

# %%
for idx, row in df.iterrows():
    row["age"] = 0
df.age.head()
# Out:
# 0    56
# 1    57
# 2    37
# 3    40
# 4    56
# Name: age, dtype: int64

# %%
df.drop(["age"], axis=1).columns
# Out:
# Index(['job', 'education', 'default', 'housing', 'loan', 'contact', 'month',
#        'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome',
#        'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m',
#        'nr.employed', 'y'],
#       dtype='object')
